# %%
# 1. Read the file it_services_tickets_raw.csv into a DataFrame called df.

import pandas as pd
df = pd.read_csv('it_services_tickets_raw.csv')

# This reads the csv file from the location where scirpt is executed

# %%
# 2. Show the first 10 rows.
df.head(10)

# head() show first 5 records by default, head(n) shown first n records.
# Out:
#   Record_ID   ticket id ClientID             Client Name client_industry  \
# 0     10842  TCK-999513   CL1003            Auric Motors      Automotive
# 1     15782  TCK-481132   CL1014     Tidewater Utilities       Utilities
# 2      5278  TCK-840641   CL1009              Kite Foods            Fmcg
# 3     35045  TCK-490788   CL1007  Pioneer Health Systems      Healthcare
# 4     34707  TCK-652326   CL1012         Orchid Airlines        Aviation
# 5      6244  TCK-399139   CL1004  Blue Harbour Logistics       Logistics
# 6     29182  TCK-646921   CL1000          Northwind Bank         Banking
# 7     30044  TCK-347822   CL1024         Sundial Apparel         Apparel
# 8     28485  TCK-313166   CL1027          Willow Biotech   Biotechnology
# 9      5489  TCK-874804   CL1007  Pioneer Health Systems      Healthcare
#
#   Client_Country client city       Contract Type              ServiceLine  \
# 0        Germany    MÃ¼nchen  Staff Augmentation             ERP Services
# 1            USA    Portland          Staff Aug.             Service Desk
# 2          India        Pune           Fixed-Bid      Application Support
# 3  United States      Boston            RETAINER       Network Operations
# 4      Singapore   Singapore    managed services      Application Support
# 5    Netherlands   Rotterdam           staff aug      Application Support
# 6  United States   Charlotte    Managed Services  Application Development
# 7     Bangladesh       Dhaka           Fixed Bid             Service Desk
# 8         France        Lyon            RETAINER           CLOUD & DEVOPS
# 9  United States      Boston            FixedBid             Service Desk
#
#   project_code  ... EngineerLevel engineer_experience_years  \
# 0  PRJ365-2024  ...       Level 2                         1
# 1  PRJ785-2023  ...       Level 1                       4.1
# 2  PRJ213-2025  ...            l2                       5.1
# 3  PRJ442-2025  ...       LEVEL-2                     6 yrs
# 4  PRJ855-2022  ...       LEVEL-1                         1
# 5  PRJ965-2024  ...     Architect                      13.5
# 6  PRJ937-2021  ...       LEVEL-3                       7.6
# 7  PRJ378-2020  ...           NaN                         4
# 8  PRJ435-2025  ...        Tier 3                        10
# 9  PRJ864-2023  ...            L1                   missing
#
#   Billing Rate (USD) hours_logged Billable Amount USD SLA_Hours  \
# 0             $39.45            ?           $1,089.21        24
# 1              33.15         1.34            USD 44.4         4
# 2               48.1            7             missing        72
# 3              52.98        34.63              1834.7  24 hours
# 4           USD 22.9        12.76           USD 292.5        24
# 5          USD 119.5         15.3          USD 1827.7        72
# 6           USD 74.8           --          USD 4609.3        72
# 7              48.06            9           USD 420.5        24
# 8              72.37         1.66             $120.13         4
# 9             $28.23     11.1 hrs              312.22        72
#
#   resolution time hours SLA Breached CSAT Score  \
# 0                  27.3          Yes          2
# 1                  2.65            0          5
# 2                   NaN         TRUE        NaN
# 3                 33.54            Y        NaN
# 4                   NaN            N        NaN
# 5                   NaN            N        NaN
# 6                 93.48          Yes         --
# 7                  8.55            N          5
# 8                  1.86        FALSE        NaN
# 9                 35.27            0          -
#
#                                     Customer Comment
# 0  Fix applied, but the workaround was manual, ne...
# 1                                                NaN
# 2  "Excellent support", said our ops lead. Will r...
# 3                       Thanks,\nissue is fixed now.
# 4                                                 --
# 5            No update provided, SLA clearly missed.
# 6  Report was wrong, numbers did not tie out, had...
# 7  Ticket bounced between L1 and L2, took far too...
# 8  The ticket was closed without confirming with ...
# 9  Issue recurred after 2 days - reopening may be...
#
# [10 rows x 29 columns]

# %%
# 3. Show the last 10 rows.

df.tail(10)

# tail() show last 5 records by default, last(n) shown last n records.
# Out:
#       Record_ID   ticket id ClientID        Client Name  client_industry  \
# 19609     41300  TCK-424599   CL1002      Vertex Pharma  Pharmaceuticals
# 19610      4339  TCK-766351   CL1019   Redstone Defence        Aerospace
# 19611     11508  TCK-275720   CL1019   Redstone Defence        Aerospace
# 19612       755  TCK-599511   CL1015      Sierra Mining           Mining
# 19613      9726  TCK-942647   CL1018     Halcyon Hotels      Hospitality
# 19614     14252  TCK-385414   CL1019   Redstone Defence        Aerospace
# 19615      9339  TCK-346330   CL1016    Copperleaf Agro      Agriculture
# 19616      7434  TCK-757238   CL1017  Nimbus Cloudworks       Technology
# 19617     13902  TCK-970364   CL1009         Kite Foods             FMCG
# 19618     45956  TCK-969118   CL1005    Saffron Telecom          telecom
#
#       Client_Country client city       Contract Type  \
# 19609    Switzerland     ZÃ¼rich    managed services
# 19610  United States  Huntsville            RETAINER
# 19611             US  Huntsville     Time & Material
# 19612         Brazil  SÃ£o Paulo    Managed Services
# 19613          Spain   Barcelona    MANAGED SERVICES
# 19614  united states  Huntsville     TIME & MATERIAL
# 19615          India      Nagpur            Retainer
# 19616        Ireland      Dublin  Staff Augmentation
# 19617          India        Pune            retainer
# 19618          India   Bengaluru     time & material
#
#                      ServiceLine project_code  ... EngineerLevel  \
# 19609             Cloud & DevOps  PRJ653-2023  ...       LEVEL-1
# 19610           Data & Analytics  PRJ471-2024  ...       Level 3
# 19611    Application Development  PRJ663-2023  ...       LEVEL-2
# 19612               Service Desk  PRJ106-2019  ...       Level 1
# 19613  Infrastructure Management  PRJ142-2024  ...     Architect
# 19614              Cybersecurity  PRJ580-2025  ...            L1
# 19615               Service Desk  PRJ566-2024  ...        Tier 3
# 19616        Quality Engineering  PRJ738-2022  ...        Tier 2
# 19617             Cloud & DevOps  PRJ134-2021  ...            L3
# 19618    Application Development  PRJ599-2019  ...            L4
#
#       engineer_experience_years Billing Rate (USD) hours_logged  \
# 19609                       1.1              24.41        57.21
# 19610                      10.3              12500            7
# 19611                       5.7              54.02        38.39
# 19612                       2.9              25.08         18.8
# 19613                      12.1          USD 121.3         2.53
# 19614                         1             $29.81           43
# 19615                       8.9              81.63        11.73
# 19616                        --             $38.76      missing
# 19617                       9.7              58.59           12
# 19618                      16.4          USD 109.7        31.21
#
#       Billable Amount USD SLA_Hours resolution time hours SLA Breached  \
# 19609            1,396.50  24 hours                 86.66         TRUE
# 19610               90250         8                  9.35          Yes
# 19611           $2,073.83        72                   NaN            -
# 19612           USD 471.5        72                   NaN           No
# 19613              545.44         4                  7.03          Yes
# 19614             1288.39        72                 40.72            N
# 19615              957.52        24                   NaN        FALSE
# 19616              127.13        72                  4.28        FALSE
# 19617              729.45        72                   NaN          Yes
# 19618          USD 3422.8        72                   NaN         TRUE
#
#       CSAT Score                                   Customer Comment
# 19609          3  Fix applied, but the workaround was manual, ne...
# 19610        NaN  Fix applied, but the workaround was manual, ne...
# 19611          -  Patch deployed in the maintenance window; down...
# 19612        NaN  Data refresh job failed again, third time this...
# 19613        NaN  "Excellent support", said our ops lead. Will r...
# 19614          2                                                NaN
# 19615        NaN                                                NaN
# 19616          3                                                NaN
# 19617        NaN                                                  ?
# 19618        NaN  Called three times, no response until escalati...
#
# [10 rows x 29 columns]

# %%
# 4. Print how many rows and how many columns the table has.

print("rows: ", df.shape[0])
print("columns: ", df.shape[1])

# shape[0] is rows 19619 and shape[1] is columns 29
# Out:
# rows:  19619
# columns:  29

# %%
# 5. Print the names of all the columns.
df.columns

# shows the names of all columns
# Out:
# Index(['Record_ID', 'ticket id', 'ClientID', 'Client Name', 'client_industry',
#        'Client_Country', 'client city', 'Contract Type', 'ServiceLine',
#        'project_code', 'Engagement Start Date', 'engagement_end_date',
#        'Ticket_Created_At', 'ticket resolved at', 'PRIORITY', 'Status',
#        'category', 'Assigned Engineer', 'engineer_Email', 'EngineerLevel',
#        'engineer_experience_years', 'Billing Rate (USD)', 'hours_logged',
#        'Billable Amount USD', 'SLA_Hours', 'resolution time hours',
#        'SLA Breached', 'CSAT Score', 'Customer Comment'],
#       dtype='str')

# %%
# 6. Print the data type of each column.
df.dtypes
# all have string data type
# Out:
# Record_ID                    str
# ticket id                    str
# ClientID                     str
# Client Name                  str
# client_industry              str
# Client_Country               str
# client city                  str
# Contract Type                str
# ServiceLine                  str
# project_code                 str
# Engagement Start Date        str
# engagement_end_date          str
# Ticket_Created_At            str
# ticket resolved at           str
# PRIORITY                     str
# Status                       str
# category                     str
# Assigned Engineer            str
# engineer_Email               str
# EngineerLevel                str
# engineer_experience_years    str
# Billing Rate (USD)           str
# hours_logged                 str
# Billable Amount USD          str
# SLA_Hours                    str
# resolution time hours        str
# SLA Breached                 str
# CSAT Score                   str
# Customer Comment             str
# dtype: object

# %%
# 7.	Run df.info() and write one line about what it tells you.
df.info()
# It shows the column name and its no of non-nullable values and datatype and total memory usages
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19619 entries, 0 to 19618
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record_ID                  19227 non-null  str
#  1   ticket id                  19619 non-null  str
#  2   ClientID                   19619 non-null  str
#  3   Client Name                19619 non-null  str
#  4   client_industry            19619 non-null  str
#  5   Client_Country             19619 non-null  str
#  6   client city                19619 non-null  str
#  7   Contract Type              19619 non-null  str
#  8   ServiceLine                19619 non-null  str
#  9   project_code               19619 non-null  str
#  10  Engagement Start Date      19239 non-null  str
#  11  engagement_end_date        18204 non-null  str
#  12  Ticket_Created_At          19349 non-null  str
#  13  ticket resolved at         12580 non-null  str
#  14  PRIORITY                   19253 non-null  str
#  15  Status                     19619 non-null  str
#  16  category                   19347 non-null  str
#  17  Assigned Engineer          19080 non-null  str
#  18  engineer_Email             19029 non-null  str
#  19  EngineerLevel              19242 non-null  str
#  20  engineer_experience_years  18761 non-null  str
#  21  Billing Rate (USD)         18981 non-null  str
#  22  hours_logged               18838 non-null  str
#  23  Billable Amount USD        18647 non-null  str
#  24  SLA_Hours                  19390 non-null  str
#  25  resolution time hours      12579 non-null  str
#  26  SLA Breached               19105 non-null  str
#  27  CSAT Score                 11422 non-null  str
#  28  Customer Comment           15751 non-null  str
# dtypes: str(29)
# memory usage: 4.3 MB

# %%
# 8.	Run df.describe() and look at the numeric columns.
df.describe()
#  is shows count,unique,top and frequency of data for each column
# Out:
#        Record_ID   ticket id ClientID            Client Name client_industry  \
# count      19227       19619    19619                  19619           19619
# unique     18844       19005       31                     91              91
# top        32466  TCK-212040   CL1021  Zephyr Semiconductors      Healthcare
# freq           3           3      702                    615             638
#
#        Client_Country client city Contract Type              ServiceLine  \
# count           19619       19619         19619                    19619
# unique             28          91            22                       33
# top     United States     Hsinchu      retainer  Application Development
# freq             3005         659          1329                     1754
#
#        project_code  ... EngineerLevel engineer_experience_years  \
# count         19619  ...         19242                     18761
# unique         5994  ...            26                       212
# top     PRJ414-2025  ...       Level 3                         0
# freq             11  ...          1004                       763
#
#        Billing Rate (USD) hours_logged Billable Amount USD SLA_Hours  \
# count               18981        18838               18647     19390
# unique              10530         5481               17035        14
# top                     ?            2             missing        24
# freq                   88          231                 140      4653
#
#        resolution time hours SLA Breached CSAT Score  \
# count                  12579        19105      11422
# unique                  5684           16         15
# top                  missing        FALSE          1
# freq                      77         3622       2761
#
#                                          Customer Comment
# count                                               15751
# unique                                                 80
# top     Escalated to the account manager; response aft...
# freq                                                  789
#
# [4 rows x 29 columns]

# %%
# 9.	Change all column names to lowercase, and replace spaces with underscores.
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
#  first columns are converted to lowercase and then space is replaced with underscore
# Out:
# Index(['record_id', 'ticket_id', 'clientid', 'client_name', 'client_industry',
#        'client_country', 'client_city', 'contract_type', 'serviceline',
#        'project_code', 'engagement_start_date', 'engagement_end_date',
#        'ticket_created_at', 'ticket_resolved_at', 'priority', 'status',
#        'category', 'assigned_engineer', 'engineer_email', 'engineerlevel',
#        'engineer_experience_years', 'billing_rate_(usd)', 'hours_logged',
#        'billable_amount_usd', 'sla_hours', 'resolution_time_hours',
#        'sla_breached', 'csat_score', 'customer_comment'],
#       dtype='str')

# %%
# 10.	Print how many missing values each column has.
df.isnull().sum()
# it shows how many null values each columns has
# Out:
# record_id                     392
# ticket_id                       0
# clientid                        0
# client_name                     0
# client_industry                 0
# client_country                  0
# client_city                     0
# contract_type                   0
# serviceline                     0
# project_code                    0
# engagement_start_date         380
# engagement_end_date          1415
# ticket_created_at             270
# ticket_resolved_at           7039
# priority                      366
# status                          0
# category                      272
# assigned_engineer             539
# engineer_email                590
# engineerlevel                 377
# engineer_experience_years     858
# billing_rate_(usd)            638
# hours_logged                  781
# billable_amount_usd           972
# sla_hours                     229
# resolution_time_hours        7040
# sla_breached                  514
# csat_score                   8197
# customer_comment             3868
# dtype: int64

# %%
# 11.	Print the total number of missing values in the whole table.
print(df.isnull().sum().sum())
# there are 34737 null values in the whole table
# Out:
# 34737

# %%
# 12.	Replace the text values NA, N/A, null and - with proper missing values.
import numpy as np
missing_values = ['NA', 'N/A', 'null', '-']
df = df.replace(missing_values, np.nan)
print(df.isnull().sum().sum())
# after replacing null values increase by 1782
# Out:
# 36519

# %%
36519-34737
# Out:
# 1782

# %%
# 13.	Count how many duplicate rows there are.
print(df.duplicated().sum())
# there are 239 duplicates values
# Out:
# 239

# %%
# 14.	Remove the duplicate rows and print the new number of rows.
df.drop_duplicates(inplace=True)
print(f"number of rows after removing duplicates: {df.shape[0]}")
# removed 239 records new records are 19380
# Out:
# number of rows after removing duplicates: 19380

# %%
19619-19380
# Out:
# 239

# %%
# 15.	Show only three columns: ticket id, client name and status.
df[['ticket_id', 'client_name', 'status']].head()
# show colums mentioned in the list
# Out:
#     ticket_id             client_name    status
# 0  TCK-999513            Auric Motors  Resolved
# 1  TCK-481132     Tidewater Utilities  Resolved
# 2  TCK-840641              Kite Foods      open
# 3  TCK-490788  Pioneer Health Systems  Resolved
# 4  TCK-652326         Orchid Airlines      OPEN

# %%
# 16.	Show rows 5 to 15 using iloc.
df.iloc[4:15]
# Out:
#    record_id   ticket_id clientid             client_name  client_industry  \
# 4      34707  TCK-652326   CL1012         Orchid Airlines         Aviation
# 5       6244  TCK-399139   CL1004  Blue Harbour Logistics        Logistics
# 6      29182  TCK-646921   CL1000          Northwind Bank          Banking
# 7      30044  TCK-347822   CL1024         Sundial Apparel          Apparel
# 8      28485  TCK-313166   CL1027          Willow Biotech    Biotechnology
# 9       5489  TCK-874804   CL1007  Pioneer Health Systems       Healthcare
# 10     36019  TCK-786877   CL1009              Kite Foods             FMCG
# 11     23623  TCK-939913   CL1002           Vertex Pharma  Pharmaceuticals
# 12      6130  TCK-436529   CL1001     Helios Retail Group           Retail
# 13     32792  TCK-386938   CL1006          CASCADE ENERGY           Energy
# 14     29305  TCK-650479   CL1004  Blue Harbour Logistics        Logistics
#
#     client_country client_city       contract_type                serviceline  \
# 4        Singapore   Singapore    managed services        Application Support
# 5      Netherlands   Rotterdam           staff aug        Application Support
# 6    United States   Charlotte    Managed Services    Application Development
# 7       Bangladesh       Dhaka           Fixed Bid               Service Desk
# 8           France        Lyon            RETAINER             CLOUD & DEVOPS
# 9    United States      Boston            FixedBid               Service Desk
# 10           India        Pune          Staff Aug.               ERP Services
# 11     Switzerland     ZÃ¼rich    MANAGED SERVICES  Infrastructure Management
# 12  United Kingdom  Manchester           FIXED BID        Quality Engineering
# 13          Canada     Calgary  STAFF AUGMENTATION  Infrastructure Management
# 14     Netherlands   Rotterdam           staff aug             Cloud & DevOps
#
#    project_code  ... engineerlevel engineer_experience_years  \
# 4   PRJ855-2022  ...       LEVEL-1                         1
# 5   PRJ965-2024  ...     Architect                      13.5
# 6   PRJ937-2021  ...       LEVEL-3                       7.6
# 7   PRJ378-2020  ...           NaN                         4
# 8   PRJ435-2025  ...        Tier 3                        10
# 9   PRJ864-2023  ...            L1                   missing
# 10  PRJ414-2025  ...        Tier 4                      12.6
# 11  PRJ874-2021  ...            L4                       8.1
# 12  PRJ171-2019  ...       LEVEL-3                       9.3
# 13  PRJ307-2020  ...        Tier 4                        14
# 14  PRJ747-2020  ...            l3                       5.6
#
#    billing_rate_(usd) hours_logged billable_amount_usd sla_hours  \
# 4            USD 22.9        12.76           USD 292.5        24
# 5           USD 119.5         15.3          USD 1827.7        72
# 6            USD 74.8           --          USD 4609.3        72
# 7               48.06            9           USD 420.5        24
# 8               72.37         1.66             $120.13         4
# 9              $28.23     11.1 hrs              312.22        72
# 10              90.14          NaN               582.3         4
# 11             105.99         1.44                 NaN         4
# 12              79.54        11.63              925.05         8
# 13             130.79        72.31            9,457.42        72
# 14              64.78           28             1799.59  72 hours
#
#    resolution_time_hours sla_breached csat_score  \
# 4                    NaN            N        NaN
# 5                    NaN            N        NaN
# 6                  93.48          Yes         --
# 7                   8.55            N          5
# 8                   1.86        FALSE        NaN
# 9                  35.27            0        NaN
# 10                  7.53            Y        NaN
# 11                  1.92        FALSE        NaN
# 12                 12.34          yes        NaN
# 13                 86.27         TRUE          2
# 14                   NaN           No        NaN
#
#                                      customer_comment
# 4                                                  --
# 5             No update provided, SLA clearly missed.
# 6   Report was wrong, numbers did not tie out, had...
# 7   Ticket bounced between L1 and L2, took far too...
# 8   The ticket was closed without confirming with ...
# 9   Issue recurred after 2 days - reopening may be...
# 10  Network latency persists in the Mumbai office,...
# 11  Great turnaround, engineer explained the RCA c...
# 12  Fix applied, but the workaround was manual, ne...
# 13          \tNo update provided, SLA clearly missed.
# 14  \tData refresh job failed again, third time th...
#
# [11 rows x 29 columns]

# %%
# 17.	Show the row at index 100 using loc.
df.loc[100]
# Out:
# record_id                                                      19100
# ticket_id                                                 TCK-316040
# clientid                                                      CL1019
# client_name                                         Redstone Defence
# client_industry                                            Aerospace
# client_country                                                    US
# client_city                                               Huntsville
# contract_type                                               RETAINER
# serviceline                                           Cloud & DevOps
# project_code                                             PRJ884-2024
# engagement_start_date                                        1556668
# engagement_end_date                                      31-Dec-2022
# ticket_created_at                                01/21/2021 12:02 PM
# ticket_resolved_at                               2021-01-22 23:20:26
# priority                                                           3
# status                                                      resolved
# category                                                 Enhancement
# assigned_engineer                                        Meera Zhang
# engineer_email                       meera.zhang@acme_itservices.com
# engineerlevel                                                LEVEL-1
# engineer_experience_years                                        3.4
# billing_rate_(usd)                                             31.92
# hours_logged                                                32.9 hrs
# billable_amount_usd                                        $1,048.89
# sla_hours                                                         24
# resolution_time_hours                                            NaN
# sla_breached                                                       Y
# csat_score                                                         2
# customer_comment             No update provided, SLA clearly missed.
# Name: 100, dtype: str

# %%
# 18.	Show all the tickets where priority is P1.
df[df['priority'] == 'P1']
# there are 760 rows with priority P1
# Out:
#       record_id   ticket_id clientid             client_name  client_industry  \
# 35        34045  TCK-818951   CL1010     Atlas Manufacturing    Manufacturing
# 67        38006  TCK-192113   CL1020          Fjord Maritime         Shipping
# 116        6535  TCK-980629   CL1019        Redstone Defence        Aerospace
# 131       11221  TCK-142412   CL1002           vertex pharma  Pharmaceuticals
# 192       26022  TCK-897143   CL1014     Tidewater Utilities        Utilities
# ...         ...         ...      ...                     ...              ...
# 19500     26230  TCK-631042   CL1004  Blue Harbour Logistics        Logistics
# 19511     16030  TCK-561321   CL1016         Copperleaf Agro      Agriculture
# 19571     18114  TCK-273375   CL1006          Cascade Energy           ENERGY
# 19581      9264  TCK-661206   CL1020          Fjord Maritime         Shipping
# 19593     10929  TCK-149681   CL1004  Blue Harbour Logistics        Logistics
#
#       client_country client_city       contract_type         serviceline  \
# 35            Mexico   Monterrey    Managed Services        Service Desk
# 67            Norway      Bergen            FixedBid    Data & Analytics
# 116    united states  Huntsville   Time and Material       Cybersecurity
# 131      Switzerland     ZÃ¼rich           Fixed-Bid      Cloud & Devops
# 192    united states    Portland    Managed Services    Data & Analytics
# ...              ...         ...                 ...                 ...
# 19500    Netherlands   Rotterdam  STAFF AUGMENTATION      Cloud & DevOps
# 19511          India      Nagpur          Staff Aug.  network operations
# 19571         Canada     Calgary     time & material        ERP Services
# 19581         Norway      Bergen        Managed Svcs        ERP Services
# 19593    Netherlands   Rotterdam    Managed Services        ERP Services
#
#       project_code  ... engineerlevel engineer_experience_years  \
# 35     PRJ374-2019  ...       Level 2                       1.7
# 67     PRJ698-2020  ...            l2                       1.5
# 116    PRJ953-2023  ...       Level 4                      10.5
# 131    PRJ292-2019  ...        Tier 3                       9.4
# 192    PRJ633-2023  ...        Tier 2                       3.2
# ...            ...  ...           ...                       ...
# 19500  PRJ156-2020  ...            L1                       5.4
# 19511  PRJ803-2022  ...        Tier 3                       8.4
# 19571  PRJ746-2025  ...            l1                         0
# 19581  PRJ129-2020  ...       LEVEL-1                       2.6
# 19593  PRJ842-2024  ...            l2                       3.4
#
#       billing_rate_(usd) hours_logged billable_amount_usd sla_hours  \
# 35                   NaN           13              740.69         4
# 67                $54.33          NaN            2,170.48         4
# 116               102.27     27.6 hrs          USD 2822.7         4
# 131                88.94         7.32              565.35         4
# 192                37.74           13           $1,067.56         4
# ...                  ...          ...                 ...       ...
# 19500              33.94            2               75.35         4
# 19511              79.42     37.5 hrs             2980.63         4
# 19571             $28.03         4.17              116.89         4
# 19581              28.86        25.13             $725.25   4 hours
# 19593             $44.63     10.3 hrs                 NaN         4
#
#       resolution_time_hours sla_breached csat_score  \
# 35                      NaN            0        NaN
# 67                      NaN           no        NaN
# 116                     NaN          Yes        NaN
# 131                     NaN        FALSE        NaN
# 192                     NaN            1        NaN
# ...                     ...          ...        ...
# 19500                  2.26        FALSE          1
# 19511                   NaN          Yes        NaN
# 19571                  5.14         TRUE        NaN
# 19581                   NaN            0        NaN
# 19593                 10.85          Yes          2
#
#                                         customer_comment
# 35                                                    na
# 67     Fix applied, but the workaround was manual, ne...
# 116    Access request fulfilled, however the approval...
# 131              No update provided, SLA clearly missed.
# 192    Issue recurred after 2 days - reopening may be...
# ...                                                  ...
# 19500                                                NaN
# 19511                                                 --
# 19571                                                NaN
# 19581                                                NaN
# 19593                                                 na
#
# [760 rows x 29 columns]

# %%
# 19.	Show all the tickets where status is Open.
df[df['status'] == 'Open']
# there are 1110 rows with status Open
# Out:
#       record_id   ticket_id clientid          client_name  client_industry  \
# 34        25266  TCK-307213   CL1002        Vertex Pharma  PHARMACEUTICALS
# 45        17206  TCK-515728   CL1002        Vertex Pharma  Pharmaceuticals
# 74        44539  TCK-248851   CL1009           Kite Foods             FMCG
# 76         4955  TCK-438218   CL1008   Meridian Insurance        Insurance
# 103       20386  TCK-808862   CL1003         Auric Motors       AUTOMOTIVE
# ...         ...         ...      ...                  ...              ...
# 19498     18365  TCK-985438   CL1023   everline education        Education
# 19509     34964  TCK-285818   CL1027       Willow Biotech    Biotechnology
# 19511     16030  TCK-561321   CL1016      Copperleaf Agro      Agriculture
# 19551     22700  TCK-628740   CL1014  Tidewater Utilities        utilities
# 19589     34947  TCK-523699   CL1010  Atlas Manufacturing    Manufacturing
#
#       client_country client_city     contract_type                serviceline  \
# 34       Switzerland     zÃ¼rich   TIME & MATERIAL           DATA & ANALYTICS
# 45       Switzerland     zÃ¼rich  Managed Services             cloud & devops
# 74             India        PUNE         fixed bid               ERP Services
# 76         Australia      Sydney          Retainer  Infrastructure Management
# 103          Germany    MÃ¼nchen  managed services         Network Operations
# ...              ...         ...               ...                        ...
# 19498         Canada     Toronto         FIXED BID              CYBERSECURITY
# 19509         France        Lyon      Managed Svcs        Application Support
# 19511          India      Nagpur        Staff Aug.         network operations
# 19551  United States    PORTLAND  managed services        Application Support
# 19589         Mexico   Monterrey         fixed bid           DATA & ANALYTICS
#
#       project_code  ... engineerlevel engineer_experience_years  \
# 34     PRJ364-2023  ...       Level 2                       3.9
# 45     PRJ537-2025  ...       Level 2                       NaN
# 74     PRJ330-2020  ...            L4                        na
# 76     PRJ936-2025  ...       Level 1                         1
# 103    PRJ133-2019  ...        Tier 4                      14.7
# ...            ...  ...           ...                       ...
# 19498  PRJ263-2023  ...        Tier 3                       8.9
# 19509  PRJ391-2019  ...        Tier 1                       2.5
# 19511  PRJ803-2022  ...        Tier 3                       8.4
# 19551  PRJ310-2023  ...            L2                       5.7
# 19589  PRJ664-2023  ...        Tier 2                       2.9
#
#       billing_rate_(usd) hours_logged billable_amount_usd sla_hours  \
# 34                  43.9     39.0 hrs             1713.42        24
# 45                $46.61          NaN              476.35  24 hours
# 74                     0        22.97             USD 0.0  72 hours
# 76                  27.9     24.9 hrs           USD 687.7        72
# 103                89.14         4.71             $419.85        24
# ...                  ...          ...                 ...       ...
# 19498           USD 73.1        34.39             missing         4
# 19509              29.98           11              327.38         4
# 19511              79.42     37.5 hrs             2980.63         4
# 19551             $40.79           29             1018.06         8
# 19589              36.54         19.7              719.84        24
#
#       resolution_time_hours sla_breached csat_score  \
# 34                      NaN            0        NaN
# 45                      NaN          NaN        NaN
# 74                      NaN           no        NaN
# 76                      NaN            0        NaN
# 103                     NaN          Yes        NaN
# ...                     ...          ...        ...
# 19498                   NaN      missing    missing
# 19509                   NaN            N        NaN
# 19511                   NaN          Yes        NaN
# 19551                  -2.5          NaN        NaN
# 19589                   NaN        FALSE        NaN
#
#                                         customer_comment
# 34     Great turnaround, engineer explained the RCA c...
# 45     Data refresh job failed again, third time this...
# 74                                                   NaN
# 76     Escalated to the account manager; response aft...
# 103    Data refresh job failed again, third time this...
# ...                                                  ...
# 19498                                                NaN
# 19509  Root cause was a stale config; please document...
# 19511                                                 --
# 19551  Network latency persists in the Mumbai office,...
# 19589                                                NaN
#
# [1110 rows x 29 columns]

# %%
# 20.	Count how many tickets there are for each status.
df['status'].value_counts()
# shows the count of each status but there are many duplicates status having different names.
# Out:
# status
# Resolved            2661
# resolved            2593
# Closed              2417
# RESOLVED            1299
# closed              1225
# CLOSED              1220
# Auto-Closed         1180
# Open                1110
# open                1034
# IN PROGRESS          568
# OPEN                 553
# WIP                  524
# in progress          511
# In Progress          498
# In-Progress          484
# On-Hold              215
# on hold              196
# ON HOLD              181
# On Hold              173
# Pending Customer     171
# CANCELLED            146
# Cancelled            137
# Canceled             134
# cancelled            130
# auto-closed            6
# Wip                    4
# AUTO-CLOSED            3
# canceled               2
# wip                    2
# in-progress            1
# Status                 1
# pending customer       1
# Name: count, dtype: int64

# %%
# 21.	Count how many tickets there are for each priority.
df['priority'].value_counts()
# the priority names are very inconsistent
# Out:
# priority
# 2                815
# Critical         814
# HIGH             812
# P3               810
# p1               808
# 3                807
# LOW              797
# low              794
# CRITICAL         790
# MEDIUM           789
# P1 - Critical    789
# p2               789
# p3               786
# High             782
# high             779
# 1                778
# medium           774
# Medium           773
# P4               770
# Low              764
# P2               762
# P1               760
# 4                742
# p4               729
# na                54
# missing           49
# ?                 33
# --                31
# PRIORITY           1
# Name: count, dtype: int64

# %%
# 22.	Count how many tickets there are for each service line.
df['serviceline'].value_counts()
# Out:
# serviceline
# Application Development      1729
# Application Support          1697
# Service Desk                 1686
# Infrastructure Management    1679
# Quality Engineering          1654
# Cybersecurity                1651
# Data & Analytics             1642
# Network Operations           1641
# ERP Services                 1552
# Cloud & DevOps               1504
# CYBERSECURITY                 163
# erp services                  146
# APPLICATION SUPPORT           146
# Erp Services                  143
# infrastructure management     141
# APPLICATION DEVELOPMENT       140
# cybersecurity                 139
# application development       138
# CLOUD & DEVOPS                137
# cloud & devops                137
# DATA & ANALYTICS              135
# network operations            135
# Cloud & Devops                131
# data & analytics              131
# service desk                  128
# INFRASTRUCTURE MANAGEMENT     127
# QUALITY ENGINEERING           124
# quality engineering           124
# ERP SERVICES                  123
# NETWORK OPERATIONS            121
# SERVICE DESK                  118
# application support           117
# ServiceLine                     1
# Name: count, dtype: int64

# %%
# 23.	Find how many different clients there are.
print(df['clientid'].nunique())
print(df['client_name'].nunique())

# using clientid there are 31 and using client name are 91 unique clients
# there must be clients name having different name under one client id.
# Out:
# 31
# 91

# %%
result = (
    df.groupby("clientid")["client_name"]
      .unique()
      .loc[lambda x: x.str.len() > 1]
)

print(result)
# Out:
# clientid
# CL1000     [Northwind Bank, NORTHWIND BANK, northwind bank]
# CL1001    [Helios Retail Group, helios retail group, HEL...
# CL1002        [Vertex Pharma, vertex pharma, VERTEX PHARMA]
# CL1003           [Auric Motors, auric motors, AURIC MOTORS]
# CL1004    [Blue Harbour Logistics, blue harbour logistic...
# CL1005    [Saffron Telecom, saffron telecom, SAFFRON TEL...
# CL1006     [CASCADE ENERGY, Cascade Energy, cascade energy]
# CL1007    [Pioneer Health Systems, PIONEER HEALTH SYSTEM...
# CL1008    [Meridian Insurance, meridian insurance, MERID...
# CL1009                 [Kite Foods, KITE FOODS, kite foods]
# CL1010    [Atlas Manufacturing, atlas manufacturing, ATL...
# CL1011              [Lumen Media, lumen media, LUMEN MEDIA]
# CL1012    [Orchid Airlines, ORCHID AIRLINES, orchid airl...
# CL1013    [Granite Capital, granite capital, GRANITE CAP...
# CL1014    [Tidewater Utilities, tidewater utilities, TID...
# CL1015        [Sierra Mining, sierra mining, SIERRA MINING]
# CL1016    [Copperleaf Agro, copperleaf agro, COPPERLEAF ...
# CL1017    [Nimbus Cloudworks, nimbus cloudworks, NIMBUS ...
# CL1018     [Halcyon Hotels, HALCYON HOTELS, halcyon hotels]
# CL1019    [Redstone Defence, REDSTONE DEFENCE, redstone ...
# CL1020     [Fjord Maritime, fjord maritime, FJORD MARITIME]
# CL1021    [Zephyr Semiconductors, ZEPHYR SEMICONDUCTORS,...
# CL1022        [Marlowe Legal, MARLOWE LEGAL, marlowe legal]
# CL1023    [Everline Education, everline education, EVERL...
# CL1024    [Sundial Apparel, sundial apparel, SUNDIAL APP...
# CL1025    [Quarry Construction, QUARRY CONSTRUCTION, qua...
# CL1026    [Beacon Public Services, BEACON PUBLIC SERVICE...
# CL1027     [Willow Biotech, willow biotech, WILLOW BIOTECH]
# CL1028     [Ironclad Steel, ironclad steel, IRONCLAD STEEL]
# CL1029    [Palisade Realty, PALISADE REALTY, palisade re...
# Name: client_name, dtype: object

# %%
# 24.	Print the list of all countries in the data.
df['client_country'].unique()
# there are 28 unique countries
# Out:
# <StringArray>
# [             'Germany',                  'USA',                'India',
#         'United States',            'Singapore',          'Netherlands',
#            'Bangladesh',               'France',          'Switzerland',
#        'United Kingdom',               'Canada',                   'UK',
#         'united states',               'Brazil',                   'US',
#                 'Spain',                 'U.K.', 'United Arab Emirates',
#                 'Japan',               'Norway',               'Mexico',
#             'Australia',               'Taiwan',               'U.S.A.',
#               'Ireland',        'Great Britain',       'united kingdom',
#        'Client_Country']
# Length: 28, dtype: str

# %%
# 25.	Convert the hours logged column to a number.
df['hours_logged'] = pd.to_numeric(df['hours_logged'], errors='coerce')
df['hours_logged'].dtype
# here coerce parse the invalid values that cannot be converted to numberes ot NaN
# Out:
# dtype('float64')

# %%
# 26.	Convert the billing rate column to a number. Remove the $ sign first.
df["billing_rate_(usd)"] = df['billing_rate_(usd)'].str.replace('$','')
df['billing_rate_(usd)'] = pd.to_numeric(df['billing_rate_(usd)'], errors='coerce')
df['billing_rate_(usd)']

# this first remove $ sign and convert column to number.
# Out:
# float64
# 0        39.45
# 1        33.15
# 2        48.10
# 3        52.98
# 4          NaN
#          ...
# 19614    29.81
# 19615    81.63
# 19616    38.76
# 19617    58.59
# 19618      NaN
# Name: billing_rate_(usd), Length: 19380, dtype: float64

# %%
# 27.	Convert the CSAT score column to a number.
df['csat_score'] = pd.to_numeric(df['csat_score'], errors='coerce')
df['csat_score'].dtype
# Out:
# dtype('float64')

# %%
# 28.	Print the average, the smallest and the largest value of hours logged.
print("average: ", df['hours_logged'].mean())
print("smallest: ", df['hours_logged'].min())
print("largest: ", df['hours_logged'].max())

# average of hours_logged in 64.06 smallest is -12.5 and largest is 9888.01
# Out:
# average:  64.06541881399025
# smallest:  -12.5
# largest:  9888.01

# %%
# 29.	Sort the table by hours logged from highest to lowest and show the top 10 rows.
df.sort_values(by='hours_logged', ascending = False).head(10)

# top 10 values by hours_logged from higest to loweest
# top hours logged is 9888.01
# Out:
#       record_id   ticket_id clientid             client_name  client_industry  \
# 10080     40496  TCK-653078   CL1002           Vertex Pharma  PHARMACEUTICALS
# 13065     40496  TCK-653078   CL1002           vertex pharma  PHARMACEUTICALS
# 11296     44764  TCK-521971   CL1015           Sierra Mining           Mining
# 9793       8746  TCK-175367   CL1007  Pioneer Health Systems       Healthcare
# 10125      5923  TCK-690329   CL1005         Saffron Telecom          TELECOM
# 13422     24768  TCK-551790   CL1009              Kite Foods             FMCG
# 12772      3652  TCK-164665   CL1007  Pioneer Health Systems       healthcare
# 13036     36267  TCK-969381   CL1007  Pioneer Health Systems       Healthcare
# 7456      45010  TCK-372646   CL1011             Lumen Media            Media
# 7989      23990  TCK-597339   CL1015           Sierra Mining           MINING
#
#       client_country client_city       contract_type  \
# 10080    Switzerland     zÃ¼rich     Time & Material
# 13065    Switzerland     ZÃ¼rich     Time & Material
# 11296         Brazil  SÃ£o Paulo          Staff Aug.
# 9793   United States      Boston           fixed bid
# 10125          India   Bengaluru  Staff Augmentation
# 13422          India        Pune  STAFF AUGMENTATION
# 12772  united states      Boston  STAFF AUGMENTATION
# 13036  United States      Boston            retainer
# 7456   United States      Austin           Fixed Bid
# 7989          Brazil  SÃ£o Paulo            Retainer
#
#                      serviceline project_code  ... engineerlevel  \
# 10080        Application Support  PRJ254-2023  ...     Architect
# 13065        Application Support  PRJ254-2023  ...     Architect
# 11296    Application Development  PRJ191-2024  ...        Tier 2
# 9793                Service Desk  PRJ803-2025  ...        Tier 2
# 10125  Infrastructure Management  PRJ660-2022  ...            l2
# 13422    Application Development  PRJ547-2021  ...       LEVEL-1
# 12772  Infrastructure Management  PRJ176-2024  ...       Level 4
# 13036         Network Operations  PRJ137-2025  ...       LEVEL-1
# 7456               CYBERSECURITY  PRJ757-2021  ...       Level 4
# 7989                ERP Services  PRJ285-2020  ...        Tier 3
#
#       engineer_experience_years billing_rate_(usd) hours_logged  \
# 10080                      15.2                NaN      9888.01
# 13065                      15.2                NaN      9888.01
# 11296                       5.4              46.76      8760.00
# 9793                         na                NaN      8760.00
# 10125                       3.5              50.37      8760.00
# 13422                       3.3              22.47      8760.00
# 12772                      11.9                NaN      8760.00
# 13036                       3.1                NaN      8760.00
# 7456                         --             105.77      8760.00
# 7989                        9.3                NaN      8760.00
#
#       billable_amount_usd sla_hours resolution_time_hours sla_breached  \
# 10080       USD 1103106.4        72               9028.73          Yes
# 13065       USD 1103106.4        72               9028.73          Yes
# 11296            409617.6        24                 26.97         TRUE
# 9793         USD 393148.8        72                   NaN            0
# 10125            441241.2        24                  9.24            0
# 13422            196837.2         8                  9.52         TRUE
# 12772            867502.8        72                   NaN            Y
# 13036            266391.6         4                  6.14         TRUE
# 7456         1,105,952.78        24                317.89         TRUE
# 7989         USD 646050.0        24                   NaN        FALSE
#
#       csat_score                                   customer_comment
# 10080        1.0                                                NaN
# 13065        1.0                                                NaN
# 11296        5.0  "Excellent support", said our ops lead. Will r...
# 9793         NaN                                                NaN
# 10125        9.0  The ticket was closed without confirming with ...
# 13422        3.0  Fix applied, but the workaround was manual, ne...
# 12772        NaN  Called three times, no response until escalati...
# 13036        1.0  Access request fulfilled, however the approval...
# 7456         3.0                                                NaN
# 7989         NaN  "Excellent support", said our ops lead. Will r...
#
# [10 rows x 29 columns]

# %%
# 30.	Show the 5 tickets with the highest billable amount.

df['billable_amount_usd'] = df['billable_amount_usd'].str.replace('$','')
df['billable_amount_usd']
df['billable_amount_usd'] = pd.to_numeric(df['billable_amount_usd'], errors='coerce')
df.sort_values(by = "billable_amount_usd", ascending = False).head(5)

# first replace $ and then convert to numaric and sort 
# top billable amount is 2564625.0
# Out:
#       record_id   ticket_id clientid             client_name client_industry  \
# 12321     30315  TCK-666074   CL1029         Palisade Realty     Real Estate
# 12772      3652  TCK-164665   CL1007  Pioneer Health Systems      healthcare
# 17401     46298  TCK-559251   CL1022           Marlowe Legal           Legal
# 4935       9722  TCK-211391   CL1012         Orchid Airlines        aviation
# 6810      20930  TCK-186136   CL1017       Nimbus Cloudworks      Technology
#
#        client_country client_city       contract_type  \
# 12321   United States      Denver     Time & Material
# 12772   united states      Boston  STAFF AUGMENTATION
# 17401  United Kingdom       Leeds    managed services
# 4935        Singapore   Singapore    Managed Services
# 6810          Ireland      Dublin    Managed Services
#
#                      serviceline project_code  ... engineerlevel  \
# 12321              Cybersecurity  PRJ480-2021  ...       Level 2
# 12772  Infrastructure Management  PRJ176-2024  ...       Level 4
# 17401         Network Operations  PRJ903-2022  ...        Tier 4
# 4935         Quality Engineering  PRJ985-2020  ...       LEVEL-3
# 6810               Cybersecurity  PRJ994-2022  ...            L3
#
#       engineer_experience_years billing_rate_(usd) hours_logged  \
# 12321                       5.6                NaN          NaN
# 12772                      11.9                NaN       8760.0
# 17401                      10.6              95.97       8760.0
# 4935                        6.8              88.41       8760.0
# 6810                         na              83.25       8760.0
#
#       billable_amount_usd sla_hours resolution_time_hours sla_breached  \
# 12321           2564625.0        72                188.38         TRUE
# 12772            867502.8        72                   NaN            Y
# 17401            840697.2        24                   NaN            N
# 4935             774471.6        72                 45.74           No
# 6810             729270.0        72                 33.59            0
#
#       csat_score                                   customer_comment
# 12321        1.0  Ticket bounced between L1 and L2, took far too...
# 12772        NaN  Called three times, no response until escalati...
# 17401        NaN  Escalated to the account manager; response aft...
# 4935         2.0  Great turnaround, engineer explained the RCA c...
# 6810         5.0                                                NaN
#
# [5 rows x 29 columns]

# %%
# 31.	Remove the extra spaces from the client name column.
df['client_name'] = df['client_name'].str.strip()
df['client_name']
# Out:
# 0                  Auric Motors
# 1           Tidewater Utilities
# 2                    Kite Foods
# 3        Pioneer Health Systems
# 4               Orchid Airlines
#                   ...
# 19614          Redstone Defence
# 19615           Copperleaf Agro
# 19616         Nimbus Cloudworks
# 19617                Kite Foods
# 19618           Saffron Telecom
# Name: client_name, Length: 19380, dtype: str

# %%
# 32.	Change the client name column to title case.
df['client_name'] = df['client_name'].str.title()
df['client_name'].head()
# Out:
# 0              Auric Motors
# 1       Tidewater Utilities
# 2                Kite Foods
# 3    Pioneer Health Systems
# 4           Orchid Airlines
# Name: client_name, dtype: str

# %%
# 33.	Convert the ticket created column to a date.
df['ticket_created_at'] = pd.to_datetime(df['ticket_created_at'], errors = 'coerce')
df['ticket_created_at'].dtype
df['ticket_created_at']
# pd.to_datetime() coverts to datetime format yyyy-mm-dd hh:mm:ss
# Out:
# 0       2021-02-26 13:04:00
# 1       2022-08-02 00:05:32
# 2       2022-12-01 04:54:11
# 3       2024-04-09 07:01:00
# 4       2022-08-09 12:52:11
#                 ...
# 19614   2024-10-21 14:02:00
# 19615   2021-09-30 16:12:00
# 19616   2024-06-04 23:31:00
# 19617   2020-06-12 15:31:00
# 19618   2022-08-29 15:01:00
# Name: ticket_created_at, Length: 19380, dtype: datetime64[us]

# %%
# 34.	Add a new column that holds the year of the ticket.
df['ticket_year'] = df['ticket_created_at'].dt.year
df[['ticket_created_at','ticket_year']].head()
# Out:
#     ticket_created_at  ticket_year
# 0 2021-02-26 13:04:00       2021.0
# 1 2022-08-02 00:05:32       2022.0
# 2 2022-12-01 04:54:11       2022.0
# 3 2024-04-09 07:01:00       2024.0
# 4 2022-08-09 12:52:11       2022.0

# %%
# 35.	Add a new column that holds the month of the ticket.
df['ticket_month'] = df['ticket_created_at'].dt.month
df[['ticket_created_at','ticket_month']].head()
df['ticket_month'].dtype
# by default data type of new column is float
# Out:
# dtype('float64')

# %%
# 36.	Count how many tickets were created in each year.
df['ticket_year'].value_counts()
# 2023 has highest tickets
# Out:
# ticket_year
# 2023.0    3269
# 2022.0    3103
# 2021.0    2924
# 2020.0    2310
# 2024.0    2036
# 2019.0    1022
# 2025.0     836
# 2026.0     286
# 2027.0      43
# Name: count, dtype: int64

# %%
# 37.	Add a new column called total equal to billing rate multiplied by hours logged.
df.columns
df['total_billing_rate'] = df['billing_rate_(usd)']*df['hours_logged']
df[['billing_rate_(usd)','hours_logged','total_billing_rate']].head()

# new column is created with total_billing_rate
# Out:
#    billing_rate_(usd)  hours_logged  total_billing_rate
# 0               39.45           NaN                 NaN
# 1               33.15          1.34             44.4210
# 2               48.10          7.00            336.7000
# 3               52.98         34.63           1834.6974
# 4                 NaN         12.76                 NaN

# %%
# 38.	Fill the missing values in the CSAT score column with the average CSAT score.
# df.columns
avg_csat_score = df['csat_score'].mean()
print("average csat score: ", avg_csat_score)
df['csat_score'] = df['csat_score'].fillna(avg_csat_score)
df['csat_score'].isnull().sum()
df['csat_score']
# null values are replaced with the mean value
# Out:
# average csat score:  2.683016877637131
# 0        2.000000
# 1        5.000000
# 2        2.683017
# 3        2.683017
# 4        2.683017
#            ...
# 19614    2.000000
# 19615    2.683017
# 19616    3.000000
# 19617    2.683017
# 19618    2.683017
# Name: csat_score, Length: 19380, dtype: float64

# %%
# 39.	Drop the rows where the client name is missing.
rows = df.shape[0]
df.dropna(subset=['client_name'], inplace=True)
print("dropped rows: ",rows - df.shape[0])
print(df['client_name'].isnull().sum())
# there is no null values in client_name column
# Out:
# dropped rows:  0
# 0

# %%
# 40.	Group by service line and find the average hours logged.
service_line_by_hours = df.groupby('serviceline')['hours_logged'].mean()
print(service_line_by_hours)
# CYBERSECURITY has largest hours logged
# Out:
# serviceline
# APPLICATION DEVELOPMENT       27.981782
# APPLICATION SUPPORT          113.562881
# Application Development       61.013815
# Application Support           62.334899
# CLOUD & DEVOPS                47.941635
# CYBERSECURITY                167.497823
# Cloud & DevOps                40.420499
# Cloud & Devops                52.874624
# Cybersecurity                 62.794676
# DATA & ANALYTICS              21.091515
# Data & Analytics              69.738536
# ERP SERVICES                  78.779375
# ERP Services                  50.427057
# Erp Services                  35.153542
# INFRASTRUCTURE MANAGEMENT    111.552981
# Infrastructure Management     94.806701
# NETWORK OPERATIONS            81.220568
# Network Operations            72.698470
# QUALITY ENGINEERING           48.576634
# Quality Engineering           63.620185
# SERVICE DESK                  22.267826
# Service Desk                  71.823681
# ServiceLine                         NaN
# application development       33.935755
# application support           21.225169
# cloud & devops                21.562427
# cybersecurity                 19.042981
# data & analytics              41.366186
# erp services                  71.025143
# infrastructure management     31.488614
# network operations           107.052079
# quality engineering           25.875000
# service desk                  30.759326
# Name: hours_logged, dtype: float64

# %%
# 41.	Group by priority and count the tickets.

tickets_by_priority =  df.groupby('priority').size()
print(tickets_by_priority)
# size() show the priority
# Out:
# priority
# --                31
# 1                778
# 2                815
# 3                807
# 4                742
# ?                 33
# CRITICAL         790
# Critical         814
# HIGH             812
# High             782
# LOW              797
# Low              764
# MEDIUM           789
# Medium           773
# P1               760
# P1 - Critical    789
# P2               762
# P3               810
# P4               770
# PRIORITY           1
# high             779
# low              794
# medium           774
# missing           49
# na                54
# p1               808
# p2               789
# p3               786
# p4               729
# dtype: int64

# %%
# 42.	Group by client name and find the total billable amount.
client_name_by_total_billable_amount = df.groupby('client_name')['billable_amount_usd'].sum()
print(client_name_by_total_billable_amount)
# Out:
# client_name
# Atlas Manufacturing        720094.34
# Auric Motors              1264521.23
# Beacon Public Services     458073.67
# Blue Harbour Logistics    1140841.27
# Cascade Energy             601492.93
# Client Name                     0.00
# Copperleaf Agro            640700.13
# Everline Education         536638.61
# Fjord Maritime             546520.87
# Granite Capital           1668471.69
# Halcyon Hotels             751236.25
# Helios Retail Group       1025583.55
# Ironclad Steel             496825.75
# Kite Foods                1412274.92
# Lumen Media               1200105.31
# Marlowe Legal             1797090.59
# Meridian Insurance         975074.47
# Nimbus Cloudworks         1833798.66
# Northwind Bank             386700.50
# Orchid Airlines           1388567.67
# Palisade Realty           3422120.58
# Pioneer Health Systems    3520198.40
# Quarry Construction        969948.80
# Redstone Defence          1365520.08
# Saffron Telecom           2043453.83
# Sierra Mining              871702.83
# Sundial Apparel           1138196.88
# Tidewater Utilities       1536290.14
# Vertex Pharma              447582.05
# Willow Biotech             423974.82
# Zephyr Semiconductors     1931055.42
# Name: billable_amount_usd, dtype: float64

# %%
# 43.	Find the top 5 clients by number of tickets.
top_5_clints_by_tickets = df['client_name'].value_counts().head()
print(top_5_clints_by_tickets)
# Zephyr Semiconductors has highest tickets
# Out:
# client_name
# Zephyr Semiconductors     697
# Pioneer Health Systems    688
# Orchid Airlines           677
# Halcyon Hotels            673
# Sierra Mining             668
# Name: count, dtype: int64

# %%
# 44.	Find the average CSAT score for each priority.
avg_csat_for_priority = df.groupby('priority')['csat_score'].mean()
print(avg_csat_for_priority)
#  csat score is almost same for each priority
# Out:
# priority
# --               2.522458
# 1                2.696924
# 2                2.636198
# 3                2.675597
# 4                2.677744
# ?                2.744310
# CRITICAL         2.743453
# Critical         2.636891
# HIGH             2.725085
# High             2.644264
# LOW              2.721871
# Low              2.722240
# MEDIUM           2.676265
# Medium           2.665400
# P1               2.672770
# P1 - Critical    2.622846
# P2               2.660342
# P3               2.728413
# P4               2.659377
# PRIORITY         2.683017
# high             2.700505
# low              2.676369
# medium           2.689371
# missing          2.621254
# na               2.638713
# p1               2.698579
# p2               2.645416
# p3               2.687689
# p4               2.696653
# Name: csat_score, dtype: float64

# %%
# 45.	Draw a bar chart of ticket count by service line.
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='serviceline', order = df['serviceline'].value_counts().index)
plt.title('Ticket Count by Service Line')
plt.xlabel('Ticket Count')
plt.ylabel('Service Line')
plt.show()

# %%
# 46.	Draw a histogram of hours logged.

plt.figure(figsize=(12, 3))
sns.histplot(df['hours_logged'])
plt.title('Histogram of Hours Logged')
plt.xlabel('Hours Logged')
plt.ylabel('Frequency')
plt.show()

# %%
# 47.	Show only the tickets where hours logged is more than 50.
df[df['hours_logged'] > 50]
# there are 1461 records with hours more then 50
# Out:
#       record_id   ticket_id clientid            client_name  \
# 13        32792  TCK-386938   CL1006         Cascade Energy
# 18        12283  TCK-241037   CL1015          Sierra Mining
# 20        15352  TCK-604317   CL1012        Orchid Airlines
# 22         8718  TCK-664378   CL1018         Halcyon Hotels
# 38        37553  TCK-345793   CL1010    Atlas Manufacturing
# ...         ...         ...      ...                    ...
# 19552     32295  TCK-322968   CL1013        Granite Capital
# 19574     45186  TCK-667682   CL1020         Fjord Maritime
# 19601      5568  TCK-416269   CL1021  Zephyr Semiconductors
# 19608       NaN  TCK-879610   CL1008     Meridian Insurance
# 19609     41300  TCK-424599   CL1002          Vertex Pharma
#
#           client_industry  client_country client_city       contract_type  \
# 13                 Energy          Canada     Calgary  STAFF AUGMENTATION
# 18                 Mining          Brazil  SÃ£o Paulo    MANAGED SERVICES
# 20               Aviation       Singapore   Singapore    Managed Services
# 22            Hospitality           Spain   Barcelona            RETAINER
# 38          Manufacturing          Mexico   Monterrey            FixedBid
# ...                   ...             ...         ...                 ...
# 19552  Financial Services  United Kingdom      London        Managed Svcs
# 19574            Shipping          Norway      Bergen          Staff Aug.
# 19601      Semiconductors          Taiwan     Hsinchu            retainer
# 19608           Insurance       Australia      Sydney            RETAINER
# 19609     Pharmaceuticals     Switzerland     ZÃ¼rich    managed services
#
#                      serviceline project_code  ... hours_logged  \
# 13     Infrastructure Management  PRJ307-2020  ...        72.31
# 18           Application Support  PRJ663-2024  ...       253.85
# 20              Data & Analytics  PRJ519-2019  ...        50.81
# 22                 Cybersecurity  PRJ921-2020  ...        67.94
# 38           QUALITY ENGINEERING  PRJ750-2024  ...        63.02
# ...                          ...          ...  ...          ...
# 19552  Infrastructure Management  PRJ788-2025  ...       169.00
# 19574        Quality Engineering  PRJ895-2022  ...       141.34
# 19601         Network Operations  PRJ401-2025  ...        85.00
# 19608        Application Support  PRJ496-2024  ...        69.00
# 19609             Cloud & DevOps  PRJ653-2023  ...        57.21
#
#       billable_amount_usd sla_hours resolution_time_hours sla_breached  \
# 13                    NaN        72                 86.27         TRUE
# 18               10397.70         8                302.73         TRUE
# 20                    NaN        24                 56.99         TRUE
# 22                    NaN        72                 81.86         TRUE
# 38                2170.41        72                152.66         TRUE
# ...                   ...       ...                   ...          ...
# 19552             5202.72        72                   NaN         TRUE
# 19574                 NaN        72                165.42         TRUE
# 19601            11489.37        72                 88.42          yes
# 19608                 NaN        72                 97.07            Y
# 19609                 NaN  24 hours                 86.66         TRUE
#
#       csat_score                                   customer_comment  \
# 13      2.000000          \tNo update provided, SLA clearly missed.
# 18      2.683017  Great turnaround, engineer explained the RCA c...
# 20      2.683017  "Excellent support", said our ops lead. Will r...
# 22      3.000000            No update provided, SLA clearly missed.
# 38      1.000000  Root cause was a stale config; please document...
# ...          ...                                                ...
# 19552   2.683017                                                NaN
# 19574   3.000000  "Excellent support", said our ops lead. Will r...
# 19601   2.000000  The ticket was closed without confirming with ...
# 19608   1.000000  Root cause was a stale config; please document...
# 19609   3.000000  Fix applied, but the workaround was manual, ne...
#
#       ticket_year ticket_month total_billing_rate
# 13         2022.0          7.0          9457.4249
# 18         2020.0          2.0                NaN
# 20         2022.0          5.0                NaN
# 22            NaN          NaN          1672.6828
# 38         2022.0          9.0                NaN
# ...           ...          ...                ...
# 19552      2020.0          7.0                NaN
# 19574         NaN          NaN         13554.5060
# 19601         NaN          NaN         11539.6000
# 19608      2024.0          5.0          3291.9900
# 19609      2027.0          1.0          1396.4961
#
# [1461 rows x 32 columns]

# %%
# 48.	Show the tickets where status is Closed and priority is P1.
df[(df['status'] == 'Closed') & (df['priority'] == 'P1')]

# there are 95 records with status closed and priority P1
# Out:
#       record_id   ticket_id clientid          client_name client_industry  \
# 334       15244  TCK-195840   CL1016      Copperleaf Agro     Agriculture
# 465       13536  TCK-837772   CL1024      Sundial Apparel         Apparel
# 833       15719  TCK-651585   CL1003         Auric Motors      Automotive
# 895       26142  TCK-764972   CL1000       Northwind Bank         Banking
# 1189      42990  TCK-594418   CL1018       Halcyon Hotels     hospitality
# ...         ...         ...      ...                  ...             ...
# 18359     35335  TCK-562340   CL1016      Copperleaf Agro     Agriculture
# 18393     10337  TCK-211734   CL1014  Tidewater Utilities       UTILITIES
# 18498     30177  TCK-575213   CL1012      Orchid Airlines        Aviation
# 18570     10855  TCK-835649   CL1023   Everline Education       Education
# 18853     35670  TCK-608898   CL1014  Tidewater Utilities       Utilities
#
#       client_country client_city     contract_type                serviceline  \
# 334            India      Nagpur  Managed Services  Infrastructure Management
# 465       Bangladesh       Dhaka      Managed Svcs               ERP SERVICES
# 833          Germany    MÃ¼nchen        Staff Aug.         Network Operations
# 895    united states   Charlotte         Fixed Bid         Network Operations
# 1189           Spain   Barcelona          RETAINER               Service Desk
# ...              ...         ...               ...                        ...
# 18359          India      Nagpur         staff aug        Quality Engineering
# 18393         U.S.A.    Portland         staff aug        Quality Engineering
# 18498      Singapore   Singapore          RETAINER           data & analytics
# 18570         Canada     Toronto         Fixed-Bid        Application Support
# 18853            USA    Portland         staff aug             Cloud & DevOps
#
#       project_code  ... hours_logged billable_amount_usd sla_hours  \
# 334    PRJ539-2019  ...         4.14               93.40         4
# 465    PRJ875-2022  ...         7.75              711.76         4
# 833    PRJ340-2021  ...         2.47                 NaN         4
# 895    PRJ416-2023  ...         3.85              206.36         4
# 1189   PRJ582-2021  ...         1.99              139.14         4
# ...            ...  ...          ...                 ...       ...
# 18359  PRJ670-2025  ...          NaN               19.62         4
# 18393  PRJ406-2020  ...         2.34              129.73         4
# 18498  PRJ453-2022  ...          NaN                 NaN         4
# 18570  PRJ972-2025  ...          NaN                 NaN         4
# 18853  PRJ870-2022  ...         4.45              478.95         4
#
#       resolution_time_hours sla_breached csat_score  \
# 334                     5.3         TRUE   2.683017
# 465                    9.42            1   1.000000
# 833                    3.09        FALSE   2.000000
# 895                     NaN        FALSE   3.000000
# 1189                   2.49           No   2.000000
# ...                     ...          ...        ...
# 18359                  0.97            0   4.000000
# 18393                  3.65           no   4.000000
# 18498                  9.13          yes   2.683017
# 18570                  0.77        FALSE   4.000000
# 18853                  6.48         TRUE   1.000000
#
#                                         customer_comment ticket_year  \
# 334    Great turnaround, engineer explained the RCA c...      2020.0
# 465    Ticket bounced between L1 and L2, took far too...      2023.0
# 833    "Excellent support", said our ops lead. Will r...      2019.0
# 895    Fix applied, but the workaround was manual, ne...      2025.0
# 1189                                                 NaN         NaN
# ...                                                  ...         ...
# 18359  Root cause was a stale config; please document...         NaN
# 18393                                                NaN      2022.0
# 18498  Issue recurred after 2 days - reopening may be...      2021.0
# 18570  Data refresh job failed again, third time this...      2023.0
# 18853  Patch deployed in the maintenance window; down...      2025.0
#
#       ticket_month total_billing_rate
# 334            8.0            93.3984
# 465            3.0                NaN
# 833            4.0                NaN
# 895            3.0           206.3600
# 1189           NaN           139.1408
# ...            ...                ...
# 18359          NaN                NaN
# 18393          7.0                NaN
# 18498          3.0                NaN
# 18570         11.0                NaN
# 18853          4.0           468.8075
#
# [95 rows x 32 columns]
