# %%
# 1. Read the file it_services_tickets_raw.csv into a DataFrame called df.

import pandas as pd
df = pd.read_csv('it_services_tickets_raw.csv')

# This reads the csv file from the location where scirpt is executed

# %%
# 2. Show the first 10 rows.
df.head(10)

# head() show first 5 records by default, head(n) shown first n records.
# Out:
#   Record_ID   ticket id ClientID              Client Name  client_industry  \
# 0     10842  TCK-999513   CL1003              Auric Motors      Automotive
# 1     15782  TCK-481132   CL1014     \tTidewater Utilities       Utilities
# 2      5278  TCK-840641   CL1009                Kite Foods            Fmcg
# 3     35045  TCK-490788   CL1007    Pioneer Health Systems      Healthcare
# 4     34707  TCK-652326   CL1012           Orchid Airlines        Aviation
# 5      6244  TCK-399139   CL1004    Blue Harbour Logistics       Logistics
# 6     29182  TCK-646921   CL1000            Northwind Bank         Banking
# 7     30044  TCK-347822   CL1024           Sundial Apparel         Apparel
# 8     28485  TCK-313166   CL1027            Willow Biotech   Biotechnology
# 9      5489  TCK-874804   CL1007  \tPioneer Health Systems      Healthcare
#
#   Client_Country client city       Contract Type              ServiceLine  \
# ...

# %%
# 3. Show the last 10 rows.

df.tail(10)

# tail() show last 5 records by default, last(n) shown last n records.
# Out:
#       Record_ID   ticket id ClientID          Client Name  client_industry  \
# 49578     42390  TCK-954753   CL1028        Ironclad Steel          Metals
# 49579     23150  TCK-715409   CL1008    MERIDIAN INSURANCE       Insurance
# 49580     14359  TCK-501895   CL1008  Meridian Insurance         Insurance
# 49581     36564  TCK-586687   CL1020        Fjord Maritime        Shipping
# 49582     24662  TCK-417633   CL1023    Everline Education       Education
# 49583      1727  TCK-954774   CL1008    Meridian Insurance       Insurance
# 49584      3851  TCK-760415   CL1015         Sierra Mining          Mining
# 49585     13275  TCK-393895   CL1003          Auric Motors      Automotive
# 49586      3149  TCK-990560   CL1015         Sierra Mining          Mining
# 49587     28852  TCK-531517   CL1016       Copperleaf Agro     Agriculture
#
#       Client_Country client city     Contract Type          ServiceLine  \
# ...

# %%
# 4. Print how many rows and how many columns the table has.

print("rows: ", df.shape[0])
print("columns: ", df.shape[1])

# shape[0] is rows 19619 and shape[1] is columns 29
# Out:
# rows:  49588
# columns:  29

# %%
# 5. Print the names of all the columns.
df.columns

# shows the names of all columns
# Out:
# Index(['Record_ID', 'ticket id', 'ClientID', 'Client Name ', 'client_industry',
#        'Client_Country', 'client city', 'Contract Type', 'ServiceLine',
#        'project_code', 'Engagement Start Date', 'engagement_end_date ',
#        'Ticket_Created_At', 'ticket resolved at', 'PRIORITY', 'Status',
#        'category ', 'Assigned Engineer', 'engineer_Email', 'EngineerLevel',
#        'engineer_experience_years', 'Billing Rate (USD)', 'hours_logged',
#        'Billable Amount USD', 'SLA_Hours', 'resolution time hours',
#        'SLA Breached', 'CSAT Score', 'Customer Comment'],
#       dtype='object')

# %%
# 6. Print the data type of each column.
df.dtypes
# all have object data type
# Out:
# Record_ID                    object
# ticket id                    object
# ClientID                     object
# Client Name                  object
# client_industry              object
# Client_Country               object
# client city                  object
# Contract Type                object
# ServiceLine                  object
# project_code                 object
# Engagement Start Date        object
# engagement_end_date          object
# Ticket_Created_At            object
# ticket resolved at           object
# PRIORITY                     object
# Status                       object
# category                     object
# Assigned Engineer            object
# engineer_Email               object
# EngineerLevel                object
# engineer_experience_years    object
# Billing Rate (USD)           object
# hours_logged                 object
# Billable Amount USD          object
# SLA_Hours                    object
# resolution time hours        object
# ...

# %%
# 7.	Run df.info() and write one line about what it tells you.
df.info()
# It shows the column name and its no of non-nullable values and datatype and total memory usages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49588 entries, 0 to 49587
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record_ID                  48614 non-null  object
#  1   ticket id                  49588 non-null  object
#  2   ClientID                   49588 non-null  object
#  3   Client Name                49588 non-null  object
#  4   client_industry            49588 non-null  object
#  5   Client_Country             49588 non-null  object
#  6   client city                49588 non-null  object
#  7   Contract Type              49588 non-null  object
#  8   ServiceLine                49588 non-null  object
#  9   project_code               49588 non-null  object
#  10  Engagement Start Date      48742 non-null  object
#  11  engagement_end_date        46431 non-null  object
#  12  Ticket_Created_At          48991 non-null  object
# ...

# %%
# 8.	Run df.describe() and look at the numeric columns.
df.describe()
#  is shows count,unique,top and frequency of data for each column
# Out:
#         Record_ID  ticket id ClientID            Client Name  client_industry  \
# count       48614      49588    49588                   49588           49588
# unique      46220      45859       31                     509              91
# top     Record_ID  ticket id   CL1012  Pioneer Health Systems      Healthcare
# freq            4          4     1762                    1350            1585
#
#        Client_Country client city Contract Type          ServiceLine  \
# count           49588       49588         49588                49588
# unique            136         129            22                   54
# top     United States   Singapore      retainer  Application Support
# freq             6876        1627          3345                 4329
#
#        project_code  ... EngineerLevel engineer_experience_years  \
# count         49588  ...         48702                     47642
# unique         6291  ...            27                       215
# ...

# %%
# 9.	Change all column names to lowercase, and replace spaces with underscores.
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')
df.columns
#  first columns are converted to lowercase removed any starting and tailing spaces and then space is replaced with underscore
# Out:
# Index(['record_id', 'ticket_id', 'clientid', 'client_name', 'client_industry',
#        'client_country', 'client_city', 'contract_type', 'serviceline',
#        'project_code', 'engagement_start_date', 'engagement_end_date',
#        'ticket_created_at', 'ticket_resolved_at', 'priority', 'status',
#        'category', 'assigned_engineer', 'engineer_email', 'engineerlevel',
#        'engineer_experience_years', 'billing_rate_(usd)', 'hours_logged',
#        'billable_amount_usd', 'sla_hours', 'resolution_time_hours',
#        'sla_breached', 'csat_score', 'customer_comment'],
#       dtype='object')

# %%
# 10.	Print how many missing values each column has.
df.isnull().sum()
# it shows how many null values each columns has
# Out:
# record_id                      974
# ticket_id                        0
# clientid                         0
# client_name                      0
# client_industry                  0
# client_country                   0
# client_city                      0
# contract_type                    0
# serviceline                      0
# project_code                     0
# engagement_start_date          846
# engagement_end_date           3157
# ticket_created_at              597
# ticket_resolved_at           17595
# priority                       856
# status                           0
# category                       561
# assigned_engineer             1171
# engineer_email                1363
# engineerlevel                  886
# engineer_experience_years     1946
# billing_rate_(usd)            1377
# hours_logged                  1698
# billable_amount_usd           2219
# sla_hours                      552
# resolution_time_hours        17552
# sla_breached                  1151
# ...

# %%
# 11.	Print the total number of missing values in the whole table.
print(df.isnull().sum().sum())
# there are 83205 null values in the whole table
# Out:
# 83205

# %%
# 12.	Replace the text values NA, N/A, null and - with proper missing values.
import numpy as np
missing_values = ['NA', 'N/A', 'null', '-', "missing", "?" ]

before_null_count = df.isnull().sum().sum()

df = df.replace(missing_values, np.nan)

after_null_counts = df.isnull().sum().sum()
print(after_null_counts)
print("Replaced values: ", after_null_counts - before_null_count)
# after replacing null values increase by 13811
# Out:
# 97016
# Replaced values:  13811

# %%
# 13.	Count how many duplicate rows there are.
print("Duplicate rows: ", df.duplicated().sum())
# there are 1465 duplicates values
# Out:
# Duplicate rows:  1465

# %%
# 14.	Remove the duplicate rows and print the new number of rows.
df.drop_duplicates(inplace=True)
print(f"number of rows after removing duplicates: {df.shape[0]}")
# removed 1465 records new records are 48123
# Out:
# number of rows after removing duplicates: 48123

# %%
# 15.	Show only three columns: ticket id, client name and status.
df[['ticket_id', 'client_name', 'status']].head()
# show colums mentioned in the list
# Out:
#     ticket_id             client_name     status
# 0  TCK-999513            Auric Motors  Resolved
# 1  TCK-481132   \tTidewater Utilities  Resolved
# 2  TCK-840641              Kite Foods      open
# 3  TCK-490788  Pioneer Health Systems   Resolved
# 4  TCK-652326         Orchid Airlines       OPEN

# %%
# 16.	Show rows 5 to 15 using iloc.
df.iloc[5:16]

# shows rows from 5 to 15, total 11 rows
# Out:
#    record_id   ticket_id clientid               client_name  client_industry  \
# 5       6244  TCK-399139   CL1004    Blue Harbour Logistics        Logistics
# 6      29182  TCK-646921   CL1000            Northwind Bank          Banking
# 7      30044  TCK-347822   CL1024           Sundial Apparel          Apparel
# 8      28485  TCK-313166   CL1027            Willow Biotech    Biotechnology
# 9       5489  TCK-874804   CL1007  \tPioneer Health Systems       Healthcare
# 10     36019  TCK-786877   CL1009                Kite Foods             FMCG
# 11     23623  TCK-939913   CL1002             Vertex Pharma  Pharmaceuticals
# 12      6130  TCK-436529   CL1001       Helios Retail Group           Retail
# 13     32792  TCK-386938   CL1006            CASCADE ENERGY           Energy
# 14     29305  TCK-650479   CL1004    Blue Harbour Logistics        Logistics
# 15      8434  TCK-404227   CL1001       Helios Retail Group           retail
#
# ...

# %%
# 17.	Show the row at index 100 using loc.
df.loc[100]

# shows data at 100th location whose record_id is 19100
# Out:
# record_id                                                      19100
# ticket_id                                                 TCK-316040
# clientid                                                      CL1019
# client_name                                         Redstone Defence
# client_industry                                            Aerospace
# client_country                                                    US
# client_city                                               Huntsville
# contract_type                                               RETAINER
# serviceline                                           Cloud & DevOps
# project_code                                             PRJ884-2024
# engagement_start_date                                        1556668
# engagement_end_date                                      31-Dec-2022
# ticket_created_at                                01/21/2021 12:02 PM
# ticket_resolved_at                               2021-01-22T23:20:26
# ...

# %%
# 18.	Show all the tickets where priority is P1.
priority_map = {
    # P1
    "1": "P1",
    "p1": "P1",
    "P1": "P1",
    "Critical": "P1",
    "CRITICAL": "P1",
    "P1 - Critical": "P1",

    # P2
    "2": "P2",
    "p2": "P2",
    "P2": "P2",
    "High": "P2",
    "HIGH": "P2",
    "high": "P2",

    # P3
    "3": "P3",
    "p3": "P3",
    "P3": "P3",
    "Medium": "P3",
    "MEDIUM": "P3",
    "medium": "P3",

    # P4
    "4": "P4",
    "p4": "P4",
    "P4": "P4",
    "Low": "P4",
    "LOW": "P4",
    "low": "P4",
}

# Created a normalized priority column
df["priority"] = (
    df["priority"]
    .astype(str)
    .str.strip()
    .map(priority_map)
)


df[df['priority'] == 'P1']

# there are 760 rows with priority P1
# Out:
#       record_id   ticket_id clientid             client_name  client_industry  \
# 1         15782  TCK-481132   CL1014   \tTidewater Utilities        Utilities
# 8         28485  TCK-313166   CL1027          Willow Biotech    Biotechnology
# 10        36019  TCK-786877   CL1009              Kite Foods             FMCG
# 11        23623  TCK-939913   CL1002           Vertex Pharma  Pharmaceuticals
# 16        13742  TCK-610531   CL1019        Redstone Defence        aerospace
# ...         ...         ...      ...                     ...              ...
# 49575     14602  TCK-693722   CL1026  Beacon Public Services    public sector
# 49577     35489  TCK-671380   CL1022           Marlowe Legal            Legal
# 49580     14359  TCK-501895   CL1008    Meridian Insurance          Insurance
# 49581     36564  TCK-586687   CL1020          Fjord Maritime         Shipping
# 49587     28852  TCK-531517   CL1016         Copperleaf Agro      Agriculture
#
# ...

# %%
# 19.	Show all the tickets where status is Open.
status_map = {
    "open": "open",
    "in progress": "in progress",
    "in-progress": "in progress",
    "wip": "in progress",

    "on hold": "on hold",
    "on-hold": "on hold",
    "pending customer": "on hold",

    "resolved": "resolved",

    "closed": "closed",
    "auto-closed": "closed",

    "cancelled": "cancelled",
    "canceled": "cancelled",
}

# Normalize and map the status values
df["status"] = (
    df["status"]
    .astype(str)
    .str.strip()
    .str.lower()
    .map(status_map)
)

# View records for a specific mapped status
df[df["status"] == "open"]

# there are 1110 rows with status Open
# Out:
#       record_id   ticket_id clientid             client_name  client_industry  \
# 2          5278  TCK-840641   CL1009              Kite Foods             Fmcg
# 4         34707  TCK-652326   CL1012         Orchid Airlines         Aviation
# 24        41413  TCK-203182   CL1005         Saffron Telecom          Telecom
# 30          511  TCK-995122   CL1028          Ironclad Steel           Metals
# 33         1558  TCK-795642   CL1012         Orchid Airlines         Aviation
# ...         ...         ...      ...                     ...              ...
# 49548     37316  TCK-312106   CL1002           Vertex Pharma  Pharmaceuticals
# 49557        30  TCK-499072   CL1014     TIDEWATER UTILITIES        Utilities
# 49576     14011  TCK-852252   CL1004  Blue Harbour Logistics        Logistics
# 49579     23150  TCK-715409   CL1008      MERIDIAN INSURANCE        Insurance
# 49580     14359  TCK-501895   CL1008    Meridian Insurance          Insurance
#
# ...

# %%
# 20.	Count how many tickets there are for each status.
df['status'].value_counts()

# shows the count of each status, resolved has highest no.
# Out:
# status
# resolved       16466
# closed         14965
# open            6694
# in progress     6252
# on hold         2352
# cancelled       1393
# Name: count, dtype: int64

# %%
# 21.	Count how many tickets there are for each priority.
df['priority'].value_counts()

# the priority names are very inconsistent
# Out:
# priority
# P3    11785
# P1    11718
# P2    11695
# P4    11443
# Name: count, dtype: int64

# %%
# 22.	Count how many tickets there are for each service line.

df["serviceline"] = (df["serviceline"].astype(str).str.strip().str.lower())

df['serviceline'].value_counts()

# Application Development has highest tickets
# Out:
# serviceline
# application support          4900
# application development      4864
# cybersecurity                4859
# infrastructure management    4849
# data & analytics             4812
# quality engineering          4789
# network operations           4784
# service desk                 4757
# erp services                 4755
# cloud & devops               4753
# serviceline                     1
# Name: count, dtype: int64

# %%
df.drop(index=5798, inplace=True)

# dropped 5798 row because it shows column name

# %%
# 23.	Find how many different clients there are.
print(df['clientid'].nunique())

# using clientid there are 30
# Out:
# 30

# %%
# 24.	Print the list of all countries in the data.

country_map = {
    # United States
    "usa": "United States",
    "united states": "United States",
    "us": "United States",
    "u.s.a.": "United States",

    # United Kingdom
    "uk": "United Kingdom",
    "u.k.": "United Kingdom",
    "united kingdom": "United Kingdom",
    "great britain": "United Kingdom",
}

# Normalize country values and replace aliases
df["client_country"] = (
    df["client_country"]
    .astype(str)
    .str.strip()
    .str.lower()
    .replace(country_map)
)

countries = df['client_country'].unique()
print(countries)
print("Total Countries: ", countries.size)

# there are 19 unique countries
# Out:
# ['germany' 'United States' 'india' 'singapore' 'netherlands' 'bangladesh'
#  'france' 'switzerland' 'United Kingdom' 'canada' 'brazil' 'spain'
#  'united arab emirates' 'japan' 'norway' 'mexico' 'australia' 'taiwan'
#  'ireland']
# Total Countries:  19

# %%
# 25.	Convert the hours logged column to a number.
df['hours_logged'] = pd.to_numeric(df['hours_logged'], errors='coerce')
df['hours_logged'].dtype

# here coerce parse the invalid values that cannot be converted to numberes ot NaN
# Out:
# dtype('float64')

# %%
# 26.	Convert the billing rate column to a number. Remove the $ sign first.
df["billing_rate_(usd)"] = df['billing_rate_(usd)'].str.replace('$','')
df["billing_rate_(usd)"] = df['billing_rate_(usd)'].str.replace('USD ','')
df['billing_rate_(usd)'] = pd.to_numeric(df['billing_rate_(usd)'], errors='coerce')
df['billing_rate_(usd)']

# this first remove $ sign and convert column to number.
# Out:
# 0         39.45
# 1         33.15
# 2         48.10
# 3         52.98
# 4         22.90
#           ...
# 49582     46.18
# 49583     56.14
# 49584     22.80
# 49586    116.76
# 49587     89.02
# Name: billing_rate_(usd), Length: 48122, dtype: float64

# %%
# 27.	Convert the CSAT score column to a number.
df['csat_score'] = pd.to_numeric(df['csat_score'], errors='coerce')
df['csat_score'].dtype

# csat_score converted to float64
# Out:
# dtype('float64')

# %%
# 28.	Print the average, the smallest and the largest value of hours logged.
print("average: ", df['hours_logged'].mean())
print("smallest: ", df['hours_logged'].min())
print("largest: ", df['hours_logged'].max())

# average of hours_logged in 64.06 smallest is -12.5 and largest is 9888.01
# Out:
# average:  63.16764267784735
# smallest:  -12.5
# largest:  9888.01

# %%
# 29.	Sort the table by hours logged from highest to lowest and show the top 10 rows.
df.sort_values(by='hours_logged', ascending = False).head(10)

# top 10 values by hours_logged from higest to loweest
# Out:
#       record_id   ticket_id clientid            client_name  client_industry  \
# 13065     40496  TCK-653078   CL1002          vertex pharma  PHARMACEUTICALS
# 10080     40496  TCK-653078   CL1002          Vertex Pharma  PHARMACEUTICALS
# 29723     26193  TCK-257418   CL1012        ORCHID AIRLINES         Aviation
# 5830       5328  TCK-321382   CL1014    Tidewater Utilities        Utilities
# 33622     38161  TCK-291292   CL1002          Vertex Pharma  Pharmaceuticals
# 43517     17883  TCK-162057   CL1017      Nimbus Cloudworks       Technology
# 36562     45276  TCK-345700   CL1001  Helios Retail Group             Retail
# 36695     27857  TCK-629096   CL1012        Orchid Airlines         Aviation
# 25764     41516  TCK-464746   CL1024        Sundial Apparel          Apparel
# 25476     28085  TCK-876581   CL1029      \tPalisade Realty      real estate
#
#        client_country client_city      contract_type  \
# 13065     switzerland      Zürich    Time & Material
# ...

# %%
# 30.	Show the 5 tickets with the highest billable amount.

df['billable_amount_usd'] = df['billable_amount_usd'].str.replace('$','')
df['billable_amount_usd'] = df['billable_amount_usd'].str.replace('USD ','')

df['billable_amount_usd']
df['billable_amount_usd'] = pd.to_numeric(df['billable_amount_usd'], errors='coerce')
df.sort_values(by = "billable_amount_usd", ascending = False).head(5)

# first replace $ and USD and then convert to numaric and sort
# Out:
#       record_id   ticket_id clientid            client_name  \
# 5020      20269  TCK-289309   CL1021  Zephyr Semiconductors
# 26305     20269  TCK-289309   CL1021  ZEPHYR SEMICONDUCTORS
# 12321     30315  TCK-666074   CL1029        Palisade Realty
# 42717     14949  TCK-502127   CL1000         Northwind Bank
# 13245      1772  TCK-439485   CL1013        Granite Capital
#
#           client_industry  client_country client_city       contract_type  \
# 5020       Semiconductors          taiwan     Hsinchu  Staff Augmentation
# 26305      Semiconductors          taiwan    Hsinchu   Staff Augmentation
# 12321         Real Estate   United States      Denver     Time & Material
# 42717             Banking   United States   Charlotte            Retainer
# 13245  Financial Services  United Kingdom      London     Time & Material
#
#                    serviceline project_code  ... engineerlevel  \
# 5020   application development  PRJ808-2023  ...       LEVEL-1
# ...

# %%
# 31.	Remove the extra spaces from the client name column.
df['client_name'] = df['client_name'].str.strip()
df['client_name']

# str.strip() is used to remove any leading or trailing whitespaces
# Out:
# 0                  Auric Motors
# 1           Tidewater Utilities
# 2                    Kite Foods
# 3        Pioneer Health Systems
# 4               Orchid Airlines
#                   ...
# 49582        Everline Education
# 49583        Meridian Insurance
# 49584             Sierra Mining
# 49586             Sierra Mining
# 49587           Copperleaf Agro
# Name: client_name, Length: 48122, dtype: object

# %%
# 32.	Change the client name column to title case.
df['client_name'] = df['client_name'].str.title()
df['client_name'].head()

# str.title() is used to convert to title case
# Out:
# 0              Auric Motors
# 1       Tidewater Utilities
# 2                Kite Foods
# 3    Pioneer Health Systems
# 4           Orchid Airlines
# Name: client_name, dtype: object

# %%
# 33.	Convert the ticket created column to a date.
df['ticket_created_at'] = pd.to_datetime(df['ticket_created_at'], errors = 'coerce')
df['ticket_created_at'].dtype
df['ticket_created_at']

# pd.to_datetime() coverts to datetime format yyyy-mm-dd hh:mm:ss
# Out:
# /tmp/ipykernel_324633/1355416545.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['ticket_created_at'] = pd.to_datetime(df['ticket_created_at'], errors = 'coerce')
# 0       2021-02-26 13:04:00
# 1       2022-08-02 00:05:32
# 2       2022-12-01 04:54:11
# 3       2024-04-09 07:01:00
# 4       2022-08-09 12:52:11
#                 ...
# 49582   2023-12-25 01:27:24
# 49583   2025-05-31 14:42:09
# 49584   2022-10-04 21:46:41
# 49586   2020-07-19 01:12:56
# 49587   2023-12-03 00:46:58
# Name: ticket_created_at, Length: 48122, dtype: datetime64[ns]

# %%
# 34.	Add a new column that holds the year of the ticket.
df['ticket_year'] = df['ticket_created_at'].dt.year
df[['ticket_created_at','ticket_year']].head()

#  ticket_year column is created to hold the year of the ticket.
# Out:
#     ticket_created_at  ticket_year
# 0 2021-02-26 13:04:00       2021.0
# 1 2022-08-02 00:05:32       2022.0
# 2 2022-12-01 04:54:11       2022.0
# 3 2024-04-09 07:01:00       2024.0
# 4 2022-08-09 12:52:11       2022.0

# %%
# 35.	Add a new column that holds the month of the ticket.
df['ticket_month'] = df['ticket_created_at'].dt.month
df[['ticket_created_at','ticket_month']].head()
df['ticket_month'].dtype

# ticket_month column is created to hold month. By default data type of new column is float
# Out:
# dtype('float64')

# %%
# 36.	Count how many tickets were created in each year.
df['ticket_year'].value_counts()

# 2023 has highest tickets
# Out:
# ticket_year
# 2023.0    7941
# 2022.0    7801
# 2021.0    7214
# 2020.0    5703
# 2024.0    5154
# 2019.0    2513
# 2025.0    2165
# 2026.0     710
# 2027.0     105
# Name: count, dtype: int64

# %%
# 37.	Add a new column called total equal to billing rate multiplied by hours logged.
df.columns
df['total_billing_rate'] = df['billing_rate_(usd)']*df['hours_logged']
df[['billing_rate_(usd)','hours_logged','total_billing_rate']].head()

# new column is created with total_billing_rate
# Out:
#    billing_rate_(usd)  hours_logged  total_billing_rate
# 0               39.45           NaN                 NaN
# 1               33.15          1.34             44.4210
# 2               48.10          7.00            336.7000
# 3               52.98         34.63           1834.6974
# 4               22.90         12.76            292.2040

# %%
# 38.	Fill the missing values in the CSAT score column with the average CSAT score.
# df.columns
avg_csat_score = df['csat_score'].mean()
print("average csat score: ", avg_csat_score)
df['csat_score'] = df['csat_score'].fillna(avg_csat_score)
df['csat_score'].isnull().sum()
df['csat_score']
# null values are replaced with the mean value
# Out:
# average csat score:  2.6565434396413163
# 0        2.000000
# 1        5.000000
# 2        2.656543
# 3        2.656543
# 4        2.656543
#            ...
# 49582    1.000000
# 49583    5.000000
# 49584    4.000000
# 49586    5.000000
# 49587    1.000000
# Name: csat_score, Length: 48122, dtype: float64

# %%
# 39.	Drop the rows where the client name is missing.
rows = df.shape[0]
df.dropna(subset=['client_name'], inplace=True)
print("dropped rows: ",rows - df.shape[0])
print(df['client_name'].isnull().sum())
# there is no null values in client_name column
# Out:
# dropped rows:  0
# 0

# %%
# 40.	Group by service line and find the average hours logged.
service_line_by_hours = df.groupby('serviceline')['hours_logged'].mean()
print(service_line_by_hours)
# CYBERSECURITY has largest hours logged
# Out:
# serviceline
# application development      59.330557
# application support          57.458980
# cloud & devops               44.704684
# cybersecurity                72.528423
# data & analytics             61.160195
# erp services                 59.963321
# infrastructure management    67.104685
# network operations           66.413233
# quality engineering          69.247510
# service desk                 73.851981
# Name: hours_logged, dtype: float64

# %%
# 41.	Group by priority and count the tickets.

tickets_by_priority =  df.groupby('priority').size()
print(tickets_by_priority)

# groupby on priority column and then size() show the priority count of tickets
# Out:
# priority
# P1    11718
# P2    11695
# P3    11785
# P4    11443
# dtype: int64

# %%
# 42.	Group by client name and find the total billable amount.
client_name_by_total_billable_amount = df.groupby('client_name')['billable_amount_usd'].sum()
print(client_name_by_total_billable_amount)

# groupby using client_name then associate billable_amount_usd column and find the sum for each client.
# Pioneer Health Systems has the highest billable amount
# Out:
# client_name
# Atlas Manufacturing       3.632584e+06
# Auric Motors              4.299744e+06
# Beacon Public Services    3.738641e+06
# Blue Harbour Logistics    4.291733e+06
# Cascade Energy            3.917098e+06
# Copperleaf Agro           4.581794e+06
# Everline Education        2.450874e+06
# Fjord Maritime            3.015688e+06
# Granite Capital           4.891306e+06
# Halcyon Hotels            3.425589e+06
# Helios Retail Group       3.153723e+06
# Ironclad Steel            3.559896e+06
# Kite Foods                4.371019e+06
# Lumen Media               5.313217e+06
# Marlowe Legal             4.367667e+06
# Meridian Insurance        3.655638e+06
# Nimbus Cloudworks         5.167426e+06
# Northwind Bank            4.657286e+06
# Orchid Airlines           6.093718e+06
# Palisade Realty           8.382881e+06
# Pioneer Health Systems    6.677486e+06
# Quarry Construction       3.417824e+06
# Redstone Defence          4.599212e+06
# Saffron Telecom           5.907587e+06
# ...

# %%
# 43.	Find the top 5 clients by number of tickets.
top_5_clints_by_tickets = df['client_name'].value_counts().head()
print(top_5_clints_by_tickets)

# Zephyr Semiconductors has highest tickets
# Out:
# client_name
# Orchid Airlines           1699
# Pioneer Health Systems    1693
# Vertex Pharma             1675
# Zephyr Semiconductors     1666
# Everline Education        1657
# Name: count, dtype: int64

# %%
# 44.	Find the average CSAT score for each priority.
avg_csat_for_priority = df.groupby('priority')['csat_score'].mean()
print(avg_csat_for_priority)
#  csat score is almost same for each priority
# Out:
# priority
# P1    2.659539
# P2    2.644852
# P3    2.659637
# P4    2.662028
# Name: csat_score, dtype: float64

# %%
# 45.	Draw a bar chart of ticket count by service line.
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='serviceline', order = df['serviceline'].value_counts().index)
plt.title('Ticket Count by Service Line')
plt.xlabel('Ticket Count')
plt.ylabel('Service Line')
plt.show()
# here y axis is serviceline and y axis is the ticket count of that serviceline
# form the graph we can see the Application Developement has highest ticket count and application support has lowest

# %%
# 46.	Draw a histogram of hours logged.

plt.figure(figsize=(12, 3))
sns.histplot(df['hours_logged'])
plt.title('Histogram of Hours Logged')
plt.xlabel('Hours Logged')
plt.ylabel('Frequency')
plt.show()

# as shown in histogram there are lot of enteries with 0 hours logged

# %%
# 47.	Show only the tickets where hours logged is more than 50.
df[df['hours_logged'] > 50]

# there are 1461 records with hours more then 50
# Out:
#       record_id   ticket_id clientid          client_name  client_industry  \
# 13        32792  TCK-386938   CL1006       Cascade Energy           Energy
# 18        12283  TCK-241037   CL1015        Sierra Mining           Mining
# 20        15352  TCK-604317   CL1012      Orchid Airlines         Aviation
# 22         8718  TCK-664378   CL1018       Halcyon Hotels      Hospitality
# 38        37553  TCK-345793   CL1010  Atlas Manufacturing    Manufacturing
# ...         ...         ...      ...                  ...              ...
# 49535      6503  TCK-560676   CL1000       Northwind Bank          Banking
# 49539     22725  TCK-375510   CL1002        Vertex Pharma  Pharmaceuticals
# 49541      9744  TCK-569086   CL1012      Orchid Airlines         Aviation
# 49572     43348  TCK-121144   CL1000       Northwind Bank          Banking
# 49573      8190  TCK-280276   CL1020       Fjord Maritime         Shipping
#
#       client_country client_city       contract_type  \
# ...

# %%
# 48.	Show the tickets where status is Closed and priority is P1.
df[(df['status'] == 'Closed') & (df['priority'] == 'P1')]

# there are 95 records with status closed and priority P1
# Out:
# Empty DataFrame
# Columns: [record_id, ticket_id, clientid, client_name, client_industry, client_country, client_city, contract_type, serviceline, project_code, engagement_start_date, engagement_end_date, ticket_created_at, ticket_resolved_at, priority, status, category, assigned_engineer, engineer_email, engineerlevel, engineer_experience_years, billing_rate_(usd), hours_logged, billable_amount_usd, sla_hours, resolution_time_hours, sla_breached, csat_score, customer_comment, ticket_year, ticket_month, total_billing_rate]
# Index: []
#
# [0 rows x 32 columns]

# %%
# 49.	In the SLA breached column, change Yes, Y, TRUE and 1 to True, and everything else to False.

true_values = ["yes", "y", "true", "1"]

df["sla_breached"] = (
    df["sla_breached"]
    .astype(str)
    .str.strip()
    .str.lower()
    .isin(true_values)
)

print(df["sla_breached"].value_counts())


# isin([]) reutrn true if matches the list given or return false
# Out:
# sla_breached
# False    28755
# True     19367
# Name: count, dtype: int64

# %%
# 50.	Save your cleaned table to a new CSV file.
df.to_csv('it_services_tickets_cleaned.csv', index=False)

# saved it_services_tickets_cleaned.csv
